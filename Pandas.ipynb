# %%
import pandas as pd
#pandas.Series(data, index, dtype, copy)

# %%
#Create an empty Series
s =pd.Series()
print(s)
# Out:
# Series([], dtype: float64)
# C:\Users\vc_19\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
# creating a seires from ndarray
#if data is an ndarray, then index passed must be of the same lenght. If no index is passed, then by default index will be range(n) where nn is array lenght, i.e., [0,1,2,3...... range(len(array))-1]
import pandas as pd
import numpy as np
data1 = ['a','b','c','d', 'e']
data=np.array(['a','b','c','d','e','f'])
print(data,data.shape)
print(data1)

s=pd.Series(data)
print(s)
# Out:
# ['a' 'b' 'c' 'd' 'e' 'f'] (6,)
# ['a', 'b', 'c', 'd', 'e']
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
#customize numbered index in Series
data=np.array(['a','b','c','d'])
s =pd.Series(data, index =[9,10,11,12])
print(s)
print(s[10])
# Out:
# 9     a
# 10    b
# 11    c
# 12    d
# dtype: object
# b

# %%
#creating a Dictionary in Series
data = {'a':0., 'b': 1., 'c':2., 'd':3.}
s=pd.Series(data)
print(s)

Aa=np.array(data)
print(Aa)
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64
# {'a': 0.0, 'b': 1.0, 'c': 2.0, 'd': 3.0}

# %%
#custumizing index in Series
data=np.array(['a','b','c','d'])
s =pd.Series(data, index =['d','c','b','a'])
print(s)
print(s['a'])
# Out:
# d    a
# c    b
# b    c
# a    d
# dtype: object
# d

# %%
#Creating a series directly
s=pd.Series([11,12,31], index=['a','b','c'])
print(s)
# Out:
# a    11
# b    12
# c    31
# dtype: int64

# %%
#DataFRame
#To explore or handle 2d data
#both size and information(data) are mutable(change at any point of time)
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Creating a data set of rows and 3 columns
df=pd.DataFrame(np.random.randn(6, 3), index =['a', 'b', 'c', 'd', 'f', 'h'],
               columns=['one', 'two', 'three'])

# %%
df
# Out:
#         one       two     three
# a -0.734603  0.176158 -0.524927
# b  0.141428  0.464230 -0.760865
# c  0.789809 -1.365788 -0.223879
# d -0.335872  0.720813  0.276004
# f -0.785751  1.746733  0.960858
# h  2.359968 -0.114045 -0.619493

# %%
df['four']= 'bar'

# %%
df
# Out:
#         one       two     three four
# a -0.734603  0.176158 -0.524927  bar
# b  0.141428  0.464230 -0.760865  bar
# c  0.789809 -1.365788 -0.223879  bar
# d -0.335872  0.720813  0.276004  bar
# f -0.785751  1.746733  0.960858  bar
# h  2.359968 -0.114045 -0.619493  bar

# %%
df['five'] = df['one']> 1

# %%
df
# Out:
#         one       two     three four   five
# a -0.734603  0.176158 -0.524927  bar  False
# b  0.141428  0.464230 -0.760865  bar  False
# c  0.789809 -1.365788 -0.223879  bar  False
# d -0.335872  0.720813  0.276004  bar  False
# f -0.785751  1.746733  0.960858  bar  False
# h  2.359968 -0.114045 -0.619493  bar   True

# %%
df2 = df.reindex(['a','b','c','d','e','f','g','h'])

# %%
df2
# Out:
#         one       two     three four   five
# a -0.734603  0.176158 -0.524927  bar  False
# b  0.141428  0.464230 -0.760865  bar  False
# c  0.789809 -1.365788 -0.223879  bar  False
# d -0.335872  0.720813  0.276004  bar  False
# e       NaN       NaN       NaN  NaN    NaN
# f -0.785751  1.746733  0.960858  bar  False
# g       NaN       NaN       NaN  NaN    NaN
# h  2.359968 -0.114045 -0.619493  bar   True

# %%
 df2.isna()
# Out:
#      one    two  three   four   five
# a  False  False  False  False  False
# b  False  False  False  False  False
# c  False  False  False  False  False
# d  False  False  False  False  False
# e   True   True   True   True   True
# f  False  False  False  False  False
# g   True   True   True   True   True
# h  False  False  False  False  False

# %%
df2.isna().sum()
# Out:
# one      2
# two      2
# three    2
# four     2
# five     2
# dtype: int64

# %%
df2.isna().sum().sum()
# Out:
# 10

# %%
df2
# Out:
#         one       two     three four   five
# a -0.734603  0.176158 -0.524927  bar  False
# b  0.141428  0.464230 -0.760865  bar  False
# c  0.789809 -1.365788 -0.223879  bar  False
# d -0.335872  0.720813  0.276004  bar  False
# e       NaN       NaN       NaN  NaN    NaN
# f -0.785751  1.746733  0.960858  bar  False
# g       NaN       NaN       NaN  NaN    NaN
# h  2.359968 -0.114045 -0.619493  bar   True

# %%
df2.isnull().sum().sum()
# Out:
# 10

# %%
df2.isnull().sum()
# Out:
# one      2
# two      2
# three    2
# four     2
# five     2
# dtype: int64

# %%
df2.fillna('missing')
# Out:
#         one       two     three     four     five
# a -0.734603  0.176158 -0.524927      bar    False
# b  0.141428   0.46423 -0.760865      bar    False
# c  0.789809  -1.36579 -0.223879      bar    False
# d -0.335872  0.720813  0.276004      bar    False
# e   missing   missing   missing  missing  missing
# f -0.785751   1.74673  0.960858      bar    False
# g   missing   missing   missing  missing  missing
# h   2.35997 -0.114045 -0.619493      bar     True

# %%
df2.fillna(df2.mean())
# Out:
#         one       two     three four      five
# a -0.734603  0.176158 -0.524927  bar     False
# b  0.141428  0.464230 -0.760865  bar     False
# c  0.789809 -1.365788 -0.223879  bar     False
# d -0.335872  0.720813  0.276004  bar     False
# e  0.239163  0.271350 -0.148717  NaN  0.166667
# f -0.785751  1.746733  0.960858  bar     False
# g  0.239163  0.271350 -0.148717  NaN  0.166667
# h  2.359968 -0.114045 -0.619493  bar      True

# %%
df2.mean()
# Out:
# one      0.239163
# two      0.271350
# three   -0.148717
# five     0.166667
# dtype: float64

# %%
df2.dtypes
# Out:
# one      float64
# two      float64
# three    float64
# four      object
# five      object
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, a to h
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     6 non-null      float64
#  1   two     6 non-null      float64
#  2   three   6 non-null      float64
#  3   four    6 non-null      object
#  4   five    6 non-null      object
# dtypes: float64(3), object(2)
# memory usage: 384.0+ bytes

# %%
len(df2)
# Out:
# 8

# %%
df2.size
# Out:
# 40

# %%
df2.shape
# Out:
# (8, 5)

# %%
df2.describe()
# Out:
#             one       two     three
# count  6.000000  6.000000  6.000000
# mean   0.239163  0.271350 -0.148717
# std    1.194982  1.025064  0.656519
# min   -0.785751 -1.365788 -0.760865
# 25%   -0.634920 -0.041494 -0.595851
# 50%   -0.097222  0.320194 -0.374403
# 75%    0.627714  0.656667  0.151033
# max    2.359968  1.746733  0.960858

# %%
#Explaratory Data Analysis

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.size
# Out:
# 6912

# %%
data.shape
# Out:
# (768, 9)

# %%
data.interpolate() #find the appropriatee way to fill
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#for filling the missing value with the Backward padding
#  data.fillna(method = 'bfill').head()

#for filling the missing value with the Forward padding
#  data.fillna(method = 'ffill').head()

# %%
#EDA - Explaratory Data Analysis
# to know the nature of the data
#plot graph, to get insights
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.describe().T #Transpose
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
#Histogram Define the Density of the Records
data.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000267CB8E8108>,
# ...
#       dtype=object)

# %%
#Syntax
#{DataFrame.dropna(self, axis=0, how='any', thresh= None, subset= None, inplace= False)}

# %%
import pandas as pd
import numpy as np
example = pd.DataFrame({
  "name": ["Batman", "Superman", "Joker"],
    "toy" : ["Batmobile", np.nan, "HAHA"],
    "born" : [pd.Timestamp("1956-06-26"),pd.NaT,  pd.NaT]
})

# %%
example
# Out:
#        name        toy       born
# 0    Batman  Batmobile 1956-06-26
# 1  Superman        NaN        NaT
# 2     Joker       HAHA        NaT

# %%
#Drop the rows where at least one element is missing:
example.dropna()
example
# Out:
#        name        toy       born
# 0    Batman  Batmobile 1956-06-26
# 1  Superman        NaN        NaT
# 2     Joker       HAHA        NaT

# %%
#droping the columns where at least one element is missing:
example.dropna(axis = "columns")
# Out:
#        name
# 0    Batman
# 1  Superman
# 2     Joker

# %%
#droping the row where every element is missing:
example.dropna(how = "all")
# Out:
#        name        toy       born
# 0    Batman  Batmobile 1956-06-26
# 1  Superman        NaN        NaT
# 2     Joker       HAHA        NaT

# %%
#kdroping rows with 2 nan values:
example.dropna(thresh=2)
# Out:
#      name        toy       born
# 0  Batman  Batmobile 1956-06-26
# 2   Joker       HAHA        NaT

# %%
example.dropna(thresh =3)
# Out:
#      name        toy       born
# 0  Batman  Batmobile 1956-06-26

# %%
#Define in which columns to look for missing values:
example.dropna(subset= ['name', 'born'])
# Out:
#      name        toy       born
# 0  Batman  Batmobile 1956-06-26

# %%
#Keep the DataFrame with valid Entries in the same variable:
example.dropna(inplace=True)
example
# Out:
#      name        toy       born
# 0  Batman  Batmobile 1956-06-26

# %%
# %matplotlib inline
import pandas as pd

# %%
titles = pd.read_csv('titles.csv', index_col = None)
titles.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %%
print(titles.shape)
# Out:
# (244914, 2)

# %%
cast = pd.read_csv('cast.csv', index_col = None)

# %%
cast.head(10)
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# ...

# %%
#How many movies are listed in the titles dataframe?
len(titles)
# Out:
# 244914

# %%
#How many movies are listed in the cast dataframe?
len(cast)
# Out:
# 3786176

# %%
#what are the earliest two films listed in the titles dataframe?
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 193222          Miss Jerry  1894
# 51388   The Startled Lover  1898

# %%
#how many movies have the title "Hamlet"?

len(titles[titles.title == 'Hamlet'])
# Out:
# 20

# %%
#how many movies have the title "North by Northwest"?
len(titles[titles.title == 'North by Northwest'])
# Out:
# 1

# %%
#When was the first movie titled "Hamlet" made?
titles[titles.title == 'Hamlet'].sort_values('year').head(1)
# Out:
#         title  year
# 52521  Hamlet  1910

# %%
#list all of the "Treasure Island" movies from earliest to most recent.
titles[titles.title == 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %%
#How many movies were made in the year 1950?
len(titles[titles.year == 1950])
# Out:
# 1113

# %%
#In what year has a movie titled "Batman been released"?
titles[titles.title == 'Batman']
# Out:
#          title  year
# 39349   Batman  1943
# 240896  Batman  1989

# %%
#How many movies were released in between 1950 and 1960?
len(titles[(1950 <= titles.year) & (titles.year <= 1959)])
# Out:
# 12934
